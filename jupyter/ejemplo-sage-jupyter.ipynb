# %% [markdown]
# # Ejemplo práctico estudio funciones
#
# Para este ejemplo haremos uso de
# $$f(x)=\frac{x+3}{x}.$$

# %%
f= (x+3)/x

# %% [markdown]
# Para poder representarla, hacemos uso de `plot`.

# %%
plot(f,(-10,10),ymax=10, ymin=-10)
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# La función no está definida en 0. Por tanto el dominio de definición de $f$ es $\mathbb{R}\setminus\{0\}$.
#
# En cuanto a los puntos de corte con el eje OX, lo podemos encontrar con `solve`.

# %%
solve(f,x)
# Out:
# [x == -3]

# %% [markdown]
# # Continuidad
#
# La función es contínua en todo su dominio, pues es un cociente de dos polinomios, y en el dominio el denominador no se anula. Podemos estudiar los límites laterales en el 0.

# %%
f.limit(x=0,dir="-")
# Out:
# -Infinity

# %%
f.limit(x=0,dir="+")
# Out:
# +Infinity

# %% [markdown]
# # Asíntotas

# %% [markdown]
# Por lo visto en el apartado anterior, tenemos que $f$ tiene una asíntota vertical en 0. Veamos si tiene asíntotas horizontales.

# %%
f.limit(x=oo, dir="+")
# Out:
# 1

# %%
f.limit(x=-oo, dir="-")
# Out:
# 1

# %% [markdown]
# Por lo que $f$ tiene una asíntota horizontal en $y=1$.

# %%
plot(f,(-10,10),ymax=10, ymin=-10)+plot(1,(-10,10), linestyle="--", color="gray")
# Out:
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# # Crecimiento

# %% [markdown]
# Para estudiar la monotonía de la función calculamos su derivada y dónde se anula.

# %%
df=diff(f,x)
expand(df)
# Out:
# -3/x^2

# %%
solve(df,x)
# Out:
# []

# %% [markdown]
# Al no anularse, basta ver su valor en un punto cualquiera para ver si es estrictamente positiva o negativa.

# %%
df.subs({x:1})
# Out:
# -3

# %% [markdown]
# De esta forma obtenemos que $f$ es estrictamente decreciente en todo su dominio.
#
# Como la derivada no se anula, no tiene ni máximos ni mínimos relativos.

# %% [markdown]
# # Convexidad

# %% [markdown]
# Veamos en qué signo tiene la segunda derivada.

# %%
ddf=diff(df,x)
expand(ddf)
# Out:
# 6/x^3

# %% [markdown]
# Como vemos, para $x<0$, $f''(x)<0$, y para $x>0$, $f''(x)>0$. Por tanto, $f$ será cóncava en $(-\infty,0)$ y convexa en $(0,\infty)$.

# %% [markdown]
# # Paridad

# %% [markdown]
# La función carece de paridad, pues $f(x)\neq -f(x)$ y $f(x)\neq f(-x)$.

# %%
plot(f,(-10,10),ymax=10, ymin=-10)+\
plot(f.subs({x:-x}),(-10,10), linestyle="--", color="green")+\
plot(-f,(-10,10), linestyle="--", color="red")
# Out:
# Graphics object consisting of 3 graphics primitives
